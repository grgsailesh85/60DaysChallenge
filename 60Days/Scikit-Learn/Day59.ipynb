# %%
import pandas as pd
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder

# %%
# Convert YearBuilt into Age of the House

# %%
df = pd.read_csv("House Price Prediction Dataset.csv")
df.sample(10)
# Out:
#       Id  Area  Bedrooms  Bathrooms  Floors  YearBuilt  Location  Condition  \
# 291  292  4273         6          2       2       1991  Suburban       Good
# 75    76  4553         1          1       1       2025  Suburban       Good
# 261  262  3404         5          2       1       2003  Downtown       Poor
# 284  285  3376         6          5       2       2006     Rural       Fair
# 51    52  3847         1          3       1       2024  Suburban       Good
# 48    49  2451         5          3       2       2003     Urban       Poor
# 163  164  3557         5          3       2       2022     Rural       Fair
# 190  191  4552         4          3       3       2012  Downtown  Excellent
# 292  293  1400         2          1       2       2004     Urban       Good
# 147  148  4498         6          3       3       1985  Downtown       Fair
#
#     Garage    Price
# 291     No   983993
# 75     Yes  1007938
# 261    Yes   810118
# 284    Yes   825451
# 51      No   850657
# 48     Yes   651860
# 163    Yes   838356
# 190    Yes  1157464
# 292     No   429310
# 147    Yes  1089822

# %%
df["Age"] = 2026 - df["YearBuilt"]
df.drop("YearBuilt", axis = 1, inplace = True)

# %%
df.sample(3)
# Out:
#       Id  Area  Bedrooms  Bathrooms  Floors Location Condition Garage   Price  \
# 92    93  2852         4          4       2    Urban      Fair     No  717429
# 239  240  1355         2          5       2    Rural      Fair     No  401257
# 54    55  1832         2          3       1    Urban      Good    Yes  499036
#
#      Age
# 92    18
# 239   16
# 54    41

# %%
condition_encoder = OrdinalEncoder(
    categories = [[
        "Poor", "Fair", "Good", "Excellent"
    ]]
)
df[["Condition"]] = condition_encoder.fit_transform(df[["Condition"]])

# %%
df.head(10)
# Out:
#    Id  Area  Bedrooms  Bathrooms  Floors  Location  Condition Garage    Price  \
# 0   1  2195         5          3       2  Suburban        2.0     No   579315
# 1   2  2339         3          4       1  Suburban        3.0     No   642275
# 2   3  3602         2          4       2     Urban        2.0    Yes   876550
# 3   4  4431         3          2       1     Rural        1.0     No   932643
# 4   5  3707         2          4       1     Urban        3.0     No   891461
# 5   6  4983         1          3       1     Rural        3.0    Yes  1032606
# 6   7  4137         2          3       1     Urban        1.0     No   925607
# 7   8  4492         2          4       3  Suburban        1.0    Yes   976269
# 8   9  1140         1          5       2     Urban        1.0    Yes   455690
# 9  10  4373         6          2       3  Suburban        1.0     No  1005239
#
#    Age
# 0   38
# 1   25
# 2   26
# 3    2
# 4   16
# 5   18
# 6   32
# 7   22
# 8    7
# 9   30

# %%
ohe = OneHotEncoder(
    drop = None,
    sparse_output = False,
)
garage_encoded = ohe.fit_transform(df[["Garage"]])

garage_cols = ohe.get_feature_names_out(["Garage"])
garage_df = pd.DataFrame(
    garage_encoded,
    columns = garage_cols,
    index = df.index
)
df.drop("Garage", axis = 1, inplace = True)
df = pd.concat([df, garage_df], axis = 1)

# %%
df.sample(4)
# Out:
#       Id  Area  Bedrooms  Bathrooms  Floors  Location  Condition   Price  Age  \
# 261  262  3404         5          2       1  Downtown        0.0  810118   23
# 238  239  2778         3          5       2     Rural        3.0  745141    9
# 22    23  1592         6          1       3     Rural        2.0  485580   13
# 121  122  3494         3          2       1  Downtown        2.0  835463   29
#
#      Garage_No  Garage_Yes
# 261        0.0         1.0
# 238        0.0         1.0
# 22         0.0         1.0
# 121        1.0         0.0

# %%
ohe = OneHotEncoder(
    drop = None,
    sparse_output = False,
)
location_encoded = ohe.fit_transform(df[["Location"]])

location_cols = ohe.get_feature_names_out(["Location"])
location_df = pd.DataFrame(
    location_encoded,
    columns = location_cols,
    index = df.index
)
df.drop("Location", axis = 1, inplace = True)
df = pd.concat([df, location_df], axis = 1)

# %%
df.sample(5)
# Out:
#       Id  Area  Bedrooms  Bathrooms  Floors  Condition   Price  Age  \
# 212  213  3578         4          2       3        1.0  772497   26
# 255  256  1510         5          3       1        2.0  594948    7
# 254  255   749         4          3       1        0.0  343820   38
# 247  248  3480         4          1       3        0.0  852742   36
# 198  199  2270         6          3       1        1.0  543269   35
#
#      Garage_No  Garage_Yes  Location_Downtown  Location_Rural  \
# 212        1.0         0.0                0.0             1.0
# 255        0.0         1.0                1.0             0.0
# 254        0.0         1.0                1.0             0.0
# 247        0.0         1.0                1.0             0.0
# 198        1.0         0.0                0.0             1.0
#
#      Location_Suburban  Location_Urban
# 212                0.0             0.0
# 255                0.0             0.0
# 254                0.0             0.0
# 247                0.0             0.0
# 198                0.0             0.0

# %%
df.drop("Id", axis = 1, inplace = True)

# %%
df.sample(4)
# Out:
#      Area  Bedrooms  Bathrooms  Floors  Condition   Price  Age  Garage_No  \
# 212  3578         4          2       3        1.0  772497   26        1.0
# 36   2930         4          2       1        2.0  778356    8        0.0
# 112  1653         2          5       3        2.0  545888   30        0.0
# 12   4418         2          4       1        2.0  967455    8        1.0
#
#      Garage_Yes  Location_Downtown  Location_Rural  Location_Suburban  \
# 212         0.0                0.0             1.0                0.0
# 36          1.0                0.0             0.0                0.0
# 112         1.0                0.0             0.0                0.0
# 12          0.0                0.0             1.0                0.0
#
#      Location_Urban
# 212             0.0
# 36              1.0
# 112             1.0
# 12              0.0

# %%
price_col = df.pop("Price")
df["Price"] = price_col

# %%
df.sample(4)
# Out:
#      Area  Bedrooms  Bathrooms  Floors  Condition  Age  Garage_No  Garage_Yes  \
# 21   2845         5          2       2        3.0    1        1.0         0.0
# 162  2459         3          1       2        3.0   26        0.0         1.0
# 55   4212         3          1       2        1.0   13        0.0         1.0
# 104  2517         2          1       2        0.0   27        0.0         1.0
#
#      Location_Downtown  Location_Rural  Location_Suburban  Location_Urban  \
# 21                 1.0             0.0                0.0             0.0
# 162                0.0             1.0                0.0             0.0
# 55                 0.0             1.0                0.0             0.0
# 104                0.0             0.0                0.0             1.0
#
#       Price
# 21   871713
# 162  627914
# 55   917158
# 104  590639

# %%
df.to_csv("PreProcessed_Data.csv", index = False)
